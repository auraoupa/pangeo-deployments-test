# %%
import xarray as xr
import dask
import dask.threaded
import dask.multiprocessing
from dask.distributed import Client
import numpy as np                                                                                        
import zarr

c = Client()
# Out:
# /home/alberta/anaconda2/envs/pangeo-cloud/lib/python3.6/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
c
# Out:
# <Client: scheduler='tcp://127.0.0.1:45077' processes=4 cores=8>

# %%
import sys, glob
import numpy as np
import xarray as xr
import time

# %%
# %%time
dsu=xr.open_zarr('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/zarr/eNATL60-BLBT02-SSU-1h')
dsv=xr.open_zarr('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/zarr/eNATL60-BLBT02-SSV-1h')
# Out:
# CPU times: user 7.78 s, sys: 472 ms, total: 8.25 s
# Wall time: 9.53 s

# %%
# %%time
dsu1=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSU/eNATL60-BLBT02_*2010m01*_sozocrtx.nc',parallel=True)
#dsv1=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSV/eNATL60-BLBT02_1h_*2010m01*_gridV-2D.nc',parallel=True)

dsu2=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSU/eNATL60-BLBT02_*2010m02*_sozocrtx.nc',parallel=True)
#dsv2=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSV/eNATL60-BLBT02_1h_*2010m02*_gridV-2D.nc',parallel=True)

dsu3=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSU/eNATL60-BLBT02_*2010m03*_sozocrtx.nc',parallel=True)
#dsv3=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSV/eNATL60-BLBT02_1h_*2010m03*_gridV-2D.nc',parallel=True)

dsu4=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSU/eNATL60-BLBT02_*2010m04*_sozocrtx.nc',parallel=True)
#dsv4=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSV/eNATL60-BLBT02_1h_*2010m04*_gridV-2D.nc',parallel=True)

dsu5=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSU/eNATL60-BLBT02_*2010m05*_sozocrtx.nc',parallel=True)
#dsv5=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSV/eNATL60-BLBT02_1h_*2010m05*_gridV-2D.nc',parallel=True)

dsu6=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSU/eNATL60-BLBT02_*2010m06*_sozocrtx.nc',parallel=True)
#dsv6=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSV/eNATL60-BLBT02_1h_*2010m06*_gridV-2D.nc',parallel=True)

dsu7=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSU/eNATL60-BLBT02_*2009m07*_sozocrtx.nc',parallel=True)
#dsv7=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSV/eNATL60-BLBT02_1h_*2009m07*_gridV-2D.nc',parallel=True)

dsu8=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSU/eNATL60-BLBT02_*2009m08*_sozocrtx.nc',parallel=True)
#dsv8=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSV/eNATL60-BLBT02_1h_*2009m08*_gridV-2D.nc',parallel=True)

dsu9=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSU/eNATL60-BLBT02_*2009m09*_sozocrtx.nc',parallel=True)
#dsv9=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSV/eNATL60-BLBT02_1h_*2009m09*_gridV-2D.nc',parallel=True)

dsu10=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSU/eNATL60-BLBT02_*2009m10*_sozocrtx.nc',parallel=True)
#dsv10=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSV/eNATL60-BLBT02_1h_*2009m10*_gridV-2D.nc',parallel=True)

dsu11=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSU/eNATL60-BLBT02_*2009m11*_sozocrtx.nc',parallel=True)
#dsv11=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSV/eNATL60-BLBT02_1h_*2009m11*_gridV-2D.nc',parallel=True)

dsu12=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSU/eNATL60-BLBT02_*2009m12*_sozocrtx.nc',parallel=True)
#dsv12=xr.open_mfdataset('/mnt/alberta/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/SSV/eNATL60-BLBT02_1h_*2009m12*_gridV-2D.nc',parallel=True)
# Out:
# CPU times: user 2min 18s, sys: 3min 44s, total: 6min 2s
# Wall time: 16min 3s

# %%
# !ls
# Out:
# 2019-05-09-AA-KE-transfer-freq-wavenumber-diag-NATL60-on-cloud.ipynb
# 2019-05-22-AA-KE-spectrum-freq-wavenumber-diag-NATL60-on-pc.ipynb
# 2019-05-22-AA-KE-transfer-freq-wavenumber-diag-NATL60-on-cal1.ipynb
# 2019-05-22-AA-KE-transfer-freq-wavenumber-diag-NATL60-on-occigen.py
# 2019-05-22-AA-KE-transfer-freq-wavenumber-diag-NATL60-on-pc.ipynb
# 2019-05-22-AA-KE-transfer-freq-wavenumber-diag-NATL60-on-pc.py
# 2019-05-28-AA-KE-transfer-freq-wavenumber-diag-NATL60-on-pc-debug.ipynb
# 2019-05-29-AA-KE-spectrum-freq-wavenumber-diag-NATL60-on-occigen.ipynb
# 2019-05-29-AA-KE-spectrum-freq-wavenumber-diag-NATL60-on-occigen.py
# 2019-05-29-AA-KE-spectrum-wavenumber-diag-NATL60-on-cloud.ipynb
# 2019-06-01-AA-KE-spectrum-wavenumber-diag-NATL60-JAS-only-on-cloud.ipynb
# 2019-06-07-AA-KE-spectrum-wavenumber-diag-NATL60-plot-only.ipynb
# 2019-06-07-AA-KE-transfer-freq-wavenumber-diag-plot-only-NATL60.ipynb
# 2019-06-07-AA-KE-transfer-wavenumber-diag-NATL60-JAS-only-on-cal1.ipynb
# 2019-06-07-AA-KE-transfer-wavenumber-diag-NATL60-JAS-only-on-cloud.ipynb
# 2019-06-07-AA-KE-transfer-wavenumber-diag-NATL60-JAS-only-on-pc.ipynb
# 2019-06-11-AA-KE-spectrum-wavenumber-diag-eNATL60-on-hal.ipynb
# 2019-06-12-AA-KE-spectrum-wavenumber-diag-eNATL60-on-hal-JAS-netcdf.ipynb
# 2019-06-12-AA-KE-transfert-spectrum-wavenumber-diag-eNATL60-on-hal.ipynb
# 2019-06-12-AA-KE-transfert-spectrum-wavenumber-diag-eNATL60-on-hal-JAS-netcdf.ipynb
# 2019-06-24-AA-KE-spectrum-wavenumber-diag-eNATL60-on-cloud.ipynb
# 2019-06-24-AA-KE-test-transfer-wavenumber-diag-eNATL60-JAS-only-on-cal1.ipynb
# 2019-06-25-AA-test-opening-files-on-hal.ipynb
# 2019-06-25-AA-test-opening-files-on-pc.ipynb
# dask-worker.e5284923
# dask-worker.e5284924
# dask-worker.e5284925
# dask-worker.e5284926
# dask-worker.e5284927
# dask-worker.e5284928
# dask-worker.e5284929
# dask-worker.e5284930
# dask-worker.e5284931
# dask-worker.e5284932
# dask-worker.e5284933
# dask-worker.e5284934
# dask-worker.e5299410
# dask-worker.e5299411
# dask-worker.e5299412
# dask-worker.e5299413
# dask-worker.e5299414
# dask-worker.e5299415
# dask-worker.e5299416
# dask-worker.e5299417
# dask-worker.e5299418
# dask-worker.e5299419
# dask-worker.e5299420
# dask-worker.e5299421
# dask-worker.e5300857
# dask-worker.e5300858
# dask-worker.e5300859
# dask-worker.e5300860
# dask-worker.e5300861
# dask-worker.e5300862
# dask-worker.e5300863
# dask-worker.e5300864
# dask-worker.e5300865
# dask-worker.e5300866
# dask-worker.e5300867
# dask-worker.e5300868
# dask-worker.e5301144
# dask-worker.e5301145
# dask-worker.e5301146
# dask-worker.e5301147
# dask-worker.e5301148
# dask-worker.e5301149
# dask-worker.e5301150
# dask-worker.e5301151
# dask-worker.e5301152
# dask-worker.e5301153
# dask-worker.e5301154
# dask-worker.e5301155
# dask-worker.e5301370
# dask-worker.e5301371
# dask-worker.e5301372
# dask-worker.e5301373
# dask-worker.e5301374
# dask-worker.e5301375
# dask-worker.e5301376
# dask-worker.e5301377
# dask-worker.e5301378
# dask-worker.e5301379
# dask-worker.e5301380
# dask-worker.e5301381
# dask-worker.e5306809
# dask-worker.e5306810
# dask-worker.e5306811
# dask-worker.e5306812
# dask-worker.e5306813
# dask-worker.e5306814
# dask-worker.e5306815
# dask-worker.e5306816
# dask-worker.e5306817
# dask-worker.e5306818
# dask-worker.e5306819
# dask-worker.e5306820
# dask-worker.o5284923
# dask-worker.o5284924
# dask-worker.o5284925
# dask-worker.o5284926
# dask-worker.o5284927
# dask-worker.o5284928
# dask-worker.o5284929
# dask-worker.o5284930
# dask-worker.o5284931
# dask-worker.o5284932
# dask-worker.o5284933
# dask-worker.o5284934
# dask-worker.o5299410
# dask-worker.o5299411
# dask-worker.o5299412
# dask-worker.o5299413
# dask-worker.o5299414
# dask-worker.o5299415
# dask-worker.o5299416
# dask-worker.o5299417
# dask-worker.o5299418
# dask-worker.o5299419
# dask-worker.o5299420
# dask-worker.o5299421
# dask-worker.o5300857
# dask-worker.o5300858
# dask-worker.o5300859
# dask-worker.o5300860
# dask-worker.o5300861
# dask-worker.o5300862
# dask-worker.o5300863
# dask-worker.o5300864
# dask-worker.o5300865
# dask-worker.o5300866
# dask-worker.o5300867
# dask-worker.o5300868
# dask-worker.o5301144
# dask-worker.o5301145
# dask-worker.o5301146
# dask-worker.o5301147
# dask-worker.o5301148
# dask-worker.o5301149
# dask-worker.o5301150
# dask-worker.o5301151
# dask-worker.o5301152
# dask-worker.o5301153
# dask-worker.o5301154
# dask-worker.o5301155
# dask-worker.o5301370
# dask-worker.o5301371
# dask-worker.o5301372
# dask-worker.o5301373
# dask-worker.o5301374
# dask-worker.o5301375
# dask-worker.o5301376
# dask-worker.o5301377
# dask-worker.o5301378
# dask-worker.o5301379
# dask-worker.o5301380
# dask-worker.o5301381
# dask-worker.o5306809
# dask-worker.o5306810
# dask-worker.o5306811
# dask-worker.o5306812
# dask-worker.o5306813
# dask-worker.o5306814
# dask-worker.o5306815
# dask-worker.o5306816
# dask-worker.o5306817
# dask-worker.o5306818
# dask-worker.o5306819
# dask-worker.o5306820
# dask-worker-space
# KE_Spectrum_JAS_w_k_from_1h_eNATL60-BLBT02_bis.nc
# KE_Spectrum_JAS_w_k_from_1h_eNATL60-BLBT02.nc
# KE_Spectrum_JAS_w_k_from_1h_NATL60-CJM165.nc
# KE_Spectrum_JFM_w_k_from_1h_eNATL60-BLBT02.nc
# KE_Spectrum_JFM_w_k_from_1h_NATL60-CJM165.nc
# KE_spectrum_llc4320_JFM-JAS_smallbox.png
# KE_spectrum_NATL60_JFM-JAS_smallbox.png
# KE_Transfer_Flux_JAS_w_k_from_1h_eNATL60-BLBT02.nc
# KE_Transfer_Flux_JAS_w_k_from_1h_NATL60-CJM165.nc
# KE_Transfer_Flux_JFM_w_k_from_1h_eNATL60-BLBT02.nc
# KE_Transfer_Flux_JFM_w_k_from_1h_NATL60-CJM165.nc
# list-pangeo-lib.ksh
# list-pangeo-lib.txt
# PowerSpec.py
# __pycache__
# Wavenum_freq_spec_func.py
# xscale
